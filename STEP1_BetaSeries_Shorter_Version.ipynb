# %%
import tempfile  # make a temporary directory for files
import os  # interact with the filesystem
import urllib.request  # grad data from internet
import tarfile  # extract files from tar
from subprocess import Popen, PIPE, STDOUT  # enable calling commandline

import matplotlib.pyplot as plt  # manipulate figures
import seaborn as sns  # display results
import pandas as pd   # manipulate tabular data
import nibabel as nib  # load the beta maps in python
from nilearn import plotting  # plot nifti images

# %% [markdown]
# The atlas data came from a recently published parcellation
# <https://www.ncbi.nlm.nih.gov/pubmed/28981612>_ in a publically accessible github repository.

# %%
# atlas github repo for reference:
"""https://github.com/ThomasYeoLab/CBIG/raw/master/stable_projects/\
brain_parcellation/Schaefer2018_LocalGlobal/Parcellations/MNI/"""

data_dir = '/mnt/chrastil/lab/users/lily/path_direction/localizer_beta_series_all_run_exploration'

# %% [markdown]
# # Manipulate events file so it satifies assumptions

# %%
subject_num = '043'
folder = "func"

exp1 = os.path.join(data_dir,("sub-"+subject_num),"func", ("sub-"+subject_num+"_task-boldEx_run-1_events.tsv"))
exp2 = os.path.join(data_dir,("sub-"+subject_num),"func", ("sub-"+subject_num+"_task-boldEx2_run-1_events.tsv"))
test1 = os.path.join(data_dir,("sub-"+subject_num),"func", ("sub-"+subject_num+"_task-boldRun1_run-1_events.tsv"))
test2 = os.path.join(data_dir,("sub-"+subject_num),"func", ("sub-"+subject_num+"_task-boldRun2_run-1_events.tsv"))
test3 = os.path.join(data_dir,("sub-"+subject_num),"func", ("sub-"+subject_num+"_task-boldRun3_run-1_events.tsv"))
test4 = os.path.join(data_dir,("sub-"+subject_num),"func", ("sub-"+subject_num+"_task-boldRun4_run-2_events.tsv"))
test5 = os.path.join(data_dir,("sub-"+subject_num),"func", ("sub-"+subject_num+"_task-boldRun5_run-1_events.tsv"))
test6 = os.path.join(data_dir,("sub-"+subject_num),"func", ("sub-"+subject_num+"_task-boldRun6_run-1_events.tsv"))
#  
file_list = [exp1, exp2, test1, test2, test3, test4, test5, test6]#exp1, exp2,  


for i in file_list:
#     events_df = pd.read_csv(i, sep='\t', na_values="n/a")
    events_df = pd.read_csv(i, engine='python', sep=',') 
    print(events_df.head())
    events_df.to_csv(i, sep="\t", na_rep="n/a", index=False)
# Out:
#     onset trial_type  duration
# 0   1.711          E     5.200
# 1  13.150          W     8.772
# 2  22.002          N     4.200
# 3  27.401          E     3.147
# 4  32.147          N     3.240
#     onset trial_type  duration
# 0   6.578          N     3.173
# 1  14.844          E     2.667
# 2  19.457          N     3.187
# 3  30.095          E     6.639
# 4  41.934          N     3.519
#     onset trial_type  duration
# 0   6.005          E     7.520
# 1  14.044          N     3.627
# 2  22.096          W     5.733
# 3  24.496          W     2.533
# 4  30.815          W     1.627
#     onset trial_type  duration
# 0   8.094          S     2.253
# 1  11.880          E     2.213
# 2  15.853          N     2.413
# 3  19.506          E     1.134
# 4  20.426          E     2.173
#     onset trial_type  duration
# 0  17.724          S     3.800
# 1  21.257          S     3.067
# 2  49.147          N     4.119
# 3  54.720          W     2.266
# 4  56.666          W     2.773
#     onset trial_type  duration
# 0   9.891          N     4.373
# 1  15.451          W     2.200
# 2  19.250          S     4.440
# 3  23.517          S     4.053
# 4  28.503          W     3.426
#     onset trial_type  duration
# 0  11.946          E     2.026
# 1  13.639          E     1.600
# 2  16.825          S     3.759
# 3  48.328          N     2.453
# 4  50.315          N     4.906
#     onset trial_type  duration
# 0   6.257          E     6.639
# 1  17.282          N     4.253
# 2  28.761          E     2.813
# 3  34.654          W     2.346
# 4  38.400          S     3.640

# %% [markdown]
# # Run nibs

# %%
out_dir = os.path.join(data_dir, "derivatives")
work_dir = os.path.join(out_dir, "work")

cmd = """\
nibs -c WhiteMatter CSF \
--estimator lsa \
--hrf-model glover \
-w {work_dir} \
{bids_dir} \
fmriprep   \
{out_dir} \
participant 
""".format(
           bids_dir=os.path.join(data_dir),
           out_dir=out_dir,
           work_dir=work_dir)

# Since we cannot run bash commands inside this tutorial
# we are printing the actual bash command so you can see it
# in the output
print("The Example Command:\n", cmd)

# call nibs
p = Popen(cmd, shell=True, stdout=PIPE, stderr=STDOUT)

while True:
    line = p.stdout.readline()
    if not line:
        break
    print(line)
# Out:
# The Example Command:
#  nibs -c WhiteMatter CSF --estimator lsa --hrf-model glover -w /mnt/chrastil/lab/users/lily/path_direction/localizer_beta_series_all_run_exploration/derivatives/work /mnt/chrastil/lab/users/lily/path_direction/localizer_beta_series_all_run_exploration fmriprep   /mnt/chrastil/lab/users/lily/path_direction/localizer_beta_series_all_run_exploration/derivatives participant
#
# b'210220-15:25:44,756 nipype.utils INFO:\n'
# b'\t Running nipype version 1.4.2 (latest: 1.5.1)\n'
# b'Found resting state bold run, skipping\n'
# b'Found resting state bold run, skipping\n'
# b'Found resting state bold run, skipping\n'
# b'Found resting state bold run, skipping\n'
# b'Found resting state bold run, skipping\n'
# b'Found resting state bold run, skipping\n'
# b"/home/lily/.local/lib/python3.6/site-packages/bids/layout/models.py:157: UserWarning: Accessing entities as attributes is deprecated as of 0.7. Please use the .entities dictionary instead (i.e., .entities['task'] instead of .task.\n"
# b'  % (attr, attr))\n'
# b"/home/lily/.local/lib/python3.6/site-packages/bids/layout/models.py:157: UserWarning: Accessing entities as attributes is deprecated as of 0.7. Please use the .entities dictionary instead (i.e., .entities['run'] instead of .run.\n"
# b'  % (attr, attr))\n'
# b"/home/lily/.local/lib/python3.6/site-packages/bids/layout/models.py:157: UserWarning: Accessing entities as attributes is deprecated as of 0.7. Please use the .entities dictionary instead (i.e., .entities['space'] instead of .space.\n"
# b'  % (attr, attr))\n'
# b"/home/lily/.local/lib/python3.6/site-packages/bids/layout/models.py:157: UserWarning: Accessing entities as attributes is deprecated as of 0.7. Please use the .entities dictionary instead (i.e., .entities['task'] instead of .task.\n"
# b'  % (attr, attr))\n'
# b"/home/lily/.local/lib/python3.6/site-packages/bids/layout/models.py:157: UserWarning: Accessing entities as attributes is deprecated as of 0.7. Please use the .entities dictionary instead (i.e., .entities['run'] instead of .run.\n"
# b'  % (attr, attr))\n'
# b"/home/lily/.local/lib/python3.6/site-packages/bids/layout/models.py:157: UserWarning: Accessing entities as attributes is deprecated as of 0.7. Please use the .entities dictionary instead (i.e., .entities['space'] instead of .space.\n"
# b'  % (attr, attr))\n'
# b'210220-15:51:17,304 nipype.workflow INFO:\n'
# b"\t Workflow nibetaseries_participant_wf settings: ['check', 'execution', 'logging', 'monitoring']\n"
# b'210220-15:51:21,93 nipype.workflow INFO:\n'
# b'\t Running in parallel.\n'
# b'210220-15:51:21,110 nipype.workflow INFO:\n'
# b'\t [MultiProc] Running 0 tasks, and 166 jobs ready. Free memory (GB): 226.69/226.69, Free processors: 32/32.\n'
# b'210220-15:51:21,213 nipype.workflow INFO:\n'
# b'\t [Node] Setting-up "nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node" in "/mnt/chrastil/lab/users/lily/path_direction/localizer_beta_series_all_run_exploration/derivatives/work/NiBetaSeries_work/nibetaseries_participant_wf/single_subject002_wf/betaseries_wf/33d5fb129b1d3bc264fac93e23bba419679b2986/betaseries_node".\n'
# b'210220-15:51:21,220 nipype.workflow INFO:\n'
# b'\t [Node] Setting-up "nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node" in "/mnt/chrastil/lab/users/lily/path_direction/localizer_beta_series_all_run_exploration/derivatives/work/NiBetaSeries_work/nibetaseries_participant_wf/single_subject002_wf/betaseries_wf/1f8454b36ed750d3894dc8b49b09a1da1fe41401/betaseries_node".\n'
# b'210220-15:51:21,228 nipype.workflow INFO:\n'
# b'\t [Node] Setting-up "nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node" in "/mnt/chrastil/lab/users/lily/path_direction/localizer_beta_series_all_run_exploration/derivatives/work/NiBetaSeries_work/nibetaseries_participant_wf/single_subject002_wf/betaseries_wf/e2ad21c444d6d875d993a0c986384fe717698a56/betaseries_node".\n'
# b'210220-15:51:21,235 nipype.workflow INFO:\n'
# b'\t [Node] Setting-up "nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node" in "/mnt/chrastil/lab/users/lily/path_direction/localizer_beta_series_all_run_exploration/derivatives/work/NiBetaSeries_work/nibetaseries_participant_wf/single_subject002_wf/betaseries_wf/c353a2e42145cb02496af621090cd9d3cc980bc8/betaseries_node".\n'
# b'210220-15:51:21,243 nipype.workflow INFO:\n'
# b'\t [Node] Setting-up "nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node" in "/mnt/chrastil/lab/users/lily/path_direction/localizer_beta_series_all_run_exploration/derivatives/work/NiBetaSeries_work/nibetaseries_participant_wf/single_subject002_wf/betaseries_wf/8b0d134260fe27b72492d60cce437d0e82284970/betaseries_node".\n'
# b'210220-15:51:21,250 nipype.workflow INFO:\n'
# b'\t [Node] Setting-up "nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node" in "/mnt/chrastil/lab/users/lily/path_direction/localizer_beta_series_all_run_exploration/derivatives/work/NiBetaSeries_work/nibetaseries_participant_wf/single_subject002_wf/betaseries_wf/b2fe59113e53235be842787294a554219c3aad3d/betaseries_node".\n'
# b'210220-15:51:21,261 nipype.workflow INFO:\n'
# b'\t [Node] Setting-up "nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node" in "/mnt/chrastil/lab/users/lily/path_direction/localizer_beta_series_all_run_exploration/derivatives/work/NiBetaSeries_work/nibetaseries_participant_wf/single_subject002_wf/betaseries_wf/1790ce4ebc1e9abfa630e5d8a1d0441c80fb7327/betaseries_node".\n'
# b'210220-15:51:21,270 nipype.workflow INFO:\n'
# b'\t [Node] Setting-up "nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node" in "/mnt/chrastil/lab/users/lily/path_direction/localizer_beta_series_all_run_exploration/derivatives/work/NiBetaSeries_work/nibetaseries_participant_wf/single_subject002_wf/betaseries_wf/030be5590af940896d473cb0148d02b3af582413/betaseries_node".\n'
# b'210220-15:51:21,281 nipype.workflow INFO:\n'
# b'\t [Node] Setting-up "nibetaseries_participant_wf.single_subject003_wf.betaseries_wf.betaseries_node" in "/mnt/chrastil/lab/users/lily/path_direction/localizer_beta_series_all_run_exploration/derivatives/work/NiBetaSeries_work/nibetaseries_participant_wf/single_subject003_wf/betaseries_wf/674ff7871016f0e4cef7d861b001a590bab226fb/betaseries_node".\n'
# b'210220-15:51:21,290 nipype.workflow INFO:\n'
# b'\t [Node] Setting-up "nibetaseries_participant_wf.single_subject003_wf.betaseries_wf.betaseries_node" in "/mnt/chrastil/lab/users/lily/path_direction/localizer_beta_series_all_run_exploration/derivatives/work/NiBetaSeries_work/nibetaseries_participant_wf/single_subject003_wf/betaseries_wf/fcf702c7c8b93fadcaf3c2f51af47122c9200527/betaseries_node".\n'
# b'210220-15:51:21,301 nipype.workflow INFO:\n'
# b'\t [Node] Setting-up "nibetaseries_participant_wf.single_subject003_wf.betaseries_wf.betaseries_node" in "/mnt/chrastil/lab/users/lily/path_direction/localizer_beta_series_all_run_exploration/derivatives/work/NiBetaSeries_work/nibetaseries_participant_wf/single_subject003_wf/betaseries_wf/a6a23dd0fe3617056447d37b65e7c0e7de9c6955/betaseries_node".\n'
# b'210220-15:51:21,309 nipype.workflow INFO:\n'
# b'\t [Node] Setting-up "nibetaseries_participant_wf.single_subject003_wf.betaseries_wf.betaseries_node" in "/mnt/chrastil/lab/users/lily/path_direction/localizer_beta_series_all_run_exploration/derivatives/work/NiBetaSeries_work/nibetaseries_participant_wf/single_subject003_wf/betaseries_wf/94fba9355e7e4fb5699c193d602d63105bdf6458/betaseries_node".\n'
# b'210220-15:51:21,317 nipype.workflow INFO:\n'
# b'\t [Node] Setting-up "nibetaseries_participant_wf.single_subject003_wf.betaseries_wf.betaseries_node" in "/mnt/chrastil/lab/users/lily/path_direction/localizer_beta_series_all_run_exploration/derivatives/work/NiBetaSeries_work/nibetaseries_participant_wf/single_subject003_wf/betaseries_wf/572037836e8e37876e7c96962fffdfdb7e2d1789/betaseries_node".\n'
# b'210220-15:51:21,328 nipype.workflow INFO:\n'
# b'\t [Node] Setting-up "nibetaseries_participant_wf.single_subject003_wf.betaseries_wf.betaseries_node" in "/mnt/chrastil/lab/users/lily/path_direction/localizer_beta_series_all_run_exploration/derivatives/work/NiBetaSeries_work/nibetaseries_participant_wf/single_subject003_wf/betaseries_wf/2b1f7e032c4647d36b37c5e1f84a8b3cede4de65/betaseries_node".\n'
# b'210220-15:51:21,339 nipype.workflow INFO:\n'
# b'\t [Node] Setting-up "nibetaseries_participant_wf.single_subject005_wf.betaseries_wf.betaseries_node" in "/mnt/chrastil/lab/users/lily/path_direction/localizer_beta_series_all_run_exploration/derivatives/work/NiBetaSeries_work/nibetaseries_participant_wf/single_subject005_wf/betaseries_wf/14ce200fa41fe9da5e0177f0a3c1cabfd4fe9094/betaseries_node".\n'
# b'210220-15:51:21,351 nipype.workflow INFO:\n'
# b'\t [Node] Setting-up "nibetaseries_participant_wf.single_subject005_wf.betaseries_wf.betaseries_node" in "/mnt/chrastil/lab/users/lily/path_direction/localizer_beta_series_all_run_exploration/derivatives/work/NiBetaSeries_work/nibetaseries_participant_wf/single_subject005_wf/betaseries_wf/fad8c84c0e10fee3c29c1cb0baa04933dbe82e22/betaseries_node".\n'
# b'210220-15:51:21,356 nipype.workflow INFO:\n'
# b'\t [Node] Setting-up "nibetaseries_participant_wf.single_subject005_wf.betaseries_wf.betaseries_node" in "/mnt/chrastil/lab/users/lily/path_direction/localizer_beta_series_all_run_exploration/derivatives/work/NiBetaSeries_work/nibetaseries_participant_wf/single_subject005_wf/betaseries_wf/18344970ef48dfc7b4481232399733b13ac19fdd/betaseries_node".\n'
# b'210220-15:51:21,367 nipype.workflow INFO:\n'
# b'\t [Node] Setting-up "nibetaseries_participant_wf.single_subject005_wf.betaseries_wf.betaseries_node" in "/mnt/chrastil/lab/users/lily/path_direction/localizer_beta_series_all_run_exploration/derivatives/work/NiBetaSeries_work/nibetaseries_participant_wf/single_subject005_wf/betaseries_wf/905a56fe5534e3f619ff0728214e3b676f1910d5/betaseries_node".\n'
# b'210220-15:51:21,377 nipype.workflow INFO:\n'
# b'\t [Node] Setting-up "nibetaseries_participant_wf.single_subject005_wf.betaseries_wf.betaseries_node" in "/mnt/chrastil/lab/users/lily/path_direction/localizer_beta_series_all_run_exploration/derivatives/work/NiBetaSeries_work/nibetaseries_participant_wf/single_subject005_wf/betaseries_wf/14e5c7e2cecbc40478e0b9bb54db69e7123840c9/betaseries_node".\n'
# b'210220-15:51:21,387 nipype.workflow INFO:\n'
# b'\t [Node] Setting-up "nibetaseries_participant_wf.single_subject005_wf.betaseries_wf.betaseries_node" in "/mnt/chrastil/lab/users/lily/path_direction/localizer_beta_series_all_run_exploration/derivatives/work/NiBetaSeries_work/nibetaseries_participant_wf/single_subject005_wf/betaseries_wf/e840b1ac31a28f259f574846c732e11f398d60f9/betaseries_node".\n'
# b'210220-15:51:21,400 nipype.workflow INFO:\n'
# b'\t [Node] Setting-up "nibetaseries_participant_wf.single_subject005_wf.betaseries_wf.betaseries_node" in "/mnt/chrastil/lab/users/lily/path_direction/localizer_beta_series_all_run_exploration/derivatives/work/NiBetaSeries_work/nibetaseries_participant_wf/single_subject005_wf/betaseries_wf/cbd031dd56ec446ad7b72c60df43e923650de13a/betaseries_node".\n'
# b'210220-15:51:21,412 nipype.workflow INFO:\n'
# b'\t [Node] Setting-up "nibetaseries_participant_wf.single_subject005_wf.betaseries_wf.betaseries_node" in "/mnt/chrastil/lab/users/lily/path_direction/localizer_beta_series_all_run_exploration/derivatives/work/NiBetaSeries_work/nibetaseries_participant_wf/single_subject005_wf/betaseries_wf/ee2b1cafe6ff83a5a25a46d65b41aec1cb47f349/betaseries_node".\n'
# b'210220-15:51:21,429 nipype.workflow INFO:\n'
# b'\t [Node] Setting-up "nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node" in "/mnt/chrastil/lab/users/lily/path_direction/localizer_beta_series_all_run_exploration/derivatives/work/NiBetaSeries_work/nibetaseries_participant_wf/single_subject014_wf/betaseries_wf/80043f49a24caf68993daaad10cdbbff972d18eb/betaseries_node".\n'
# b'210220-15:51:21,442 nipype.workflow INFO:\n'
# b'\t [Node] Setting-up "nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node" in "/mnt/chrastil/lab/users/lily/path_direction/localizer_beta_series_all_run_exploration/derivatives/work/NiBetaSeries_work/nibetaseries_participant_wf/single_subject014_wf/betaseries_wf/2e49c813f3079ccf6cf65bbb232bd60fe9959ee8/betaseries_node".\n'
# b'210220-15:51:21,452 nipype.workflow INFO:\n'
# b'\t [Node] Setting-up "nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node" in "/mnt/chrastil/lab/users/lily/path_direction/localizer_beta_series_all_run_exploration/derivatives/work/NiBetaSeries_work/nibetaseries_participant_wf/single_subject014_wf/betaseries_wf/c03364f14fa818e7aafb6a08b58550baa9b79e84/betaseries_node".\n'
# b'210220-15:51:21,462 nipype.workflow INFO:\n'
# b'\t [Node] Setting-up "nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node" in "/mnt/chrastil/lab/users/lily/path_direction/localizer_beta_series_all_run_exploration/derivatives/work/NiBetaSeries_work/nibetaseries_participant_wf/single_subject014_wf/betaseries_wf/d8fb2f051e99897f250843b5867fa279c0ee40f5/betaseries_node".\n'
# b'210220-15:51:21,471 nipype.workflow INFO:\n'
# b'\t [Node] Setting-up "nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node" in "/mnt/chrastil/lab/users/lily/path_direction/localizer_beta_series_all_run_exploration/derivatives/work/NiBetaSeries_work/nibetaseries_participant_wf/single_subject014_wf/betaseries_wf/1c81a66b415248341a66668f8309c2e9b9a8a44d/betaseries_node".\n'
# b'210220-15:51:21,481 nipype.workflow INFO:\n'
# b'\t [Node] Setting-up "nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node" in "/mnt/chrastil/lab/users/lily/path_direction/localizer_beta_series_all_run_exploration/derivatives/work/NiBetaSeries_work/nibetaseries_participant_wf/single_subject014_wf/betaseries_wf/46e75576f328e0ca2d8d5c4c1f042b6e04ea0ea4/betaseries_node".\n'
# b'210220-15:51:21,493 nipype.workflow INFO:\n'
# b'\t [Node] Setting-up "nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node" in "/mnt/chrastil/lab/users/lily/path_direction/localizer_beta_series_all_run_exploration/derivatives/work/NiBetaSeries_work/nibetaseries_participant_wf/single_subject014_wf/betaseries_wf/fe58470050f7932d26ede3b21bd4272d589918ee/betaseries_node".\n'
# b'210220-15:51:21,506 nipype.workflow INFO:\n'
# b'\t [Node] Setting-up "nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node" in "/mnt/chrastil/lab/users/lily/path_direction/localizer_beta_series_all_run_exploration/derivatives/work/NiBetaSeries_work/nibetaseries_participant_wf/single_subject014_wf/betaseries_wf/debfd8c75780c132be496a1f0fb7ced63e6ed590/betaseries_node".\n'
# b'210220-15:51:21,513 nipype.workflow INFO:\n'
# b'\t [Node] Setting-up "nibetaseries_participant_wf.single_subject018_wf.betaseries_wf.betaseries_node" in "/mnt/chrastil/lab/users/lily/path_direction/localizer_beta_series_all_run_exploration/derivatives/work/NiBetaSeries_work/nibetaseries_participant_wf/single_subject018_wf/betaseries_wf/5b9ffef3614ca47d59e7fa4c7ea6713d6f08c80b/betaseries_node".\n'
# b'210220-15:51:21,521 nipype.workflow INFO:\n'
# b'\t [Node] Setting-up "nibetaseries_participant_wf.single_subject018_wf.betaseries_wf.betaseries_node" in "/mnt/chrastil/lab/users/lily/path_direction/localizer_beta_series_all_run_exploration/derivatives/work/NiBetaSeries_work/nibetaseries_participant_wf/single_subject018_wf/betaseries_wf/4022f41a350bf3f2c506c6a50d5db748b6375395/betaseries_node".\n'
# b'210220-15:51:21,854 nipype.workflow INFO:\n'
# b'\t [Node] Running "betaseries_node" ("nibetaseries.interfaces.nistats.LSABetaSeries")\n'
# b'210220-15:51:21,892 nipype.workflow INFO:\n'
# b'\t [Node] Running "betaseries_node" ("nibetaseries.interfaces.nistats.LSABetaSeries")\n'
# b'210220-15:51:22,4 nipype.workflow INFO:\n'
# b'\t [Node] Running "betaseries_node" ("nibetaseries.interfaces.nistats.LSABetaSeries")\n'
# b'210220-15:51:22,64 nipype.workflow INFO:\n'
# b'\t [Node] Running "betaseries_node" ("nibetaseries.interfaces.nistats.LSABetaSeries")\n'
# b'210220-15:51:22,121 nipype.workflow INFO:\n'
# b'\t [Node] Running "betaseries_node" ("nibetaseries.interfaces.nistats.LSABetaSeries")\n'
# b'210220-15:51:22,207 nipype.workflow INFO:\n'
# b'\t [Node] Running "betaseries_node" ("nibetaseries.interfaces.nistats.LSABetaSeries")\n'
# b'210220-15:51:22,234 nipype.workflow INFO:\n'
# b'\t [Node] Running "betaseries_node" ("nibetaseries.interfaces.nistats.LSABetaSeries")\n'
# b'210220-15:51:22,252 nipype.workflow INFO:\n'
# b'\t [Node] Running "betaseries_node" ("nibetaseries.interfaces.nistats.LSABetaSeries")\n'
# b'210220-15:51:22,315 nipype.workflow INFO:\n'
# b'\t [Node] Running "betaseries_node" ("nibetaseries.interfaces.nistats.LSABetaSeries")\n'
# b'210220-15:51:22,341 nipype.workflow INFO:\n'
# b'\t [Node] Running "betaseries_node" ("nibetaseries.interfaces.nistats.LSABetaSeries")\n'
# b'210220-15:51:22,393 nipype.workflow INFO:\n'
# b'\t [Node] Running "betaseries_node" ("nibetaseries.interfaces.nistats.LSABetaSeries")\n'
# b'210220-15:51:22,408 nipype.workflow INFO:\n'
# b'\t [Node] Running "betaseries_node" ("nibetaseries.interfaces.nistats.LSABetaSeries")\n'
# b'210220-15:51:22,417 nipype.workflow INFO:\n'
# b'\t [Node] Running "betaseries_node" ("nibetaseries.interfaces.nistats.LSABetaSeries")\n'
# b'210220-15:51:22,424 nipype.workflow INFO:\n'
# b'\t [Node] Running "betaseries_node" ("nibetaseries.interfaces.nistats.LSABetaSeries")\n'
# b'210220-15:51:22,493 nipype.workflow INFO:\n'
# b'\t [Node] Running "betaseries_node" ("nibetaseries.interfaces.nistats.LSABetaSeries")\n'
# b'210220-15:51:22,503 nipype.workflow INFO:\n'
# b'\t [Node] Running "betaseries_node" ("nibetaseries.interfaces.nistats.LSABetaSeries")\n'
# b'210220-15:51:22,533 nipype.workflow INFO:\n'
# b'\t [Node] Running "betaseries_node" ("nibetaseries.interfaces.nistats.LSABetaSeries")\n'
# b'210220-15:51:22,536 nipype.workflow INFO:\n'
# b'\t [Node] Running "betaseries_node" ("nibetaseries.interfaces.nistats.LSABetaSeries")\n'
# b'210220-15:51:22,539 nipype.workflow INFO:\n'
# b'\t [Node] Running "betaseries_node" ("nibetaseries.interfaces.nistats.LSABetaSeries")\n'
# b'210220-15:51:22,568 nipype.workflow INFO:\n'
# b'\t [Node] Running "betaseries_node" ("nibetaseries.interfaces.nistats.LSABetaSeries")\n'
# b'210220-15:51:22,577 nipype.workflow INFO:\n'
# b'\t [Node] Running "betaseries_node" ("nibetaseries.interfaces.nistats.LSABetaSeries")\n'
# b'210220-15:51:22,577 nipype.workflow INFO:\n'
# b'\t [Node] Running "betaseries_node" ("nibetaseries.interfaces.nistats.LSABetaSeries")\n'
# b'210220-15:51:22,588 nipype.workflow INFO:\n'
# b'\t [Node] Running "betaseries_node" ("nibetaseries.interfaces.nistats.LSABetaSeries")\n'
# b'210220-15:51:22,603 nipype.workflow INFO:\n'
# b'\t [Node] Running "betaseries_node" ("nibetaseries.interfaces.nistats.LSABetaSeries")\n'
# b'210220-15:51:22,625 nipype.workflow INFO:\n'
# b'\t [Node] Running "betaseries_node" ("nibetaseries.interfaces.nistats.LSABetaSeries")\n'
# b'210220-15:51:22,630 nipype.workflow INFO:\n'
# b'\t [Node] Running "betaseries_node" ("nibetaseries.interfaces.nistats.LSABetaSeries")\n'
# b'210220-15:51:22,645 nipype.workflow INFO:\n'
# b'\t [Node] Running "betaseries_node" ("nibetaseries.interfaces.nistats.LSABetaSeries")\n'
# b'210220-15:51:22,646 nipype.workflow INFO:\n'
# b'\t [Node] Running "betaseries_node" ("nibetaseries.interfaces.nistats.LSABetaSeries")\n'
# b'210220-15:51:22,688 nipype.workflow INFO:\n'
# b'\t [Node] Running "betaseries_node" ("nibetaseries.interfaces.nistats.LSABetaSeries")\n'
# b'210220-15:51:22,694 nipype.workflow INFO:\n'
# b'\t [Node] Running "betaseries_node" ("nibetaseries.interfaces.nistats.LSABetaSeries")\n'
# b'210220-15:51:22,723 nipype.workflow INFO:\n'
# b'\t [Node] Running "betaseries_node" ("nibetaseries.interfaces.nistats.LSABetaSeries")\n'
# b'210220-15:51:22,736 nipype.workflow INFO:\n'
# b'\t [Node] Running "betaseries_node" ("nibetaseries.interfaces.nistats.LSABetaSeries")\n'
# b'210220-15:51:23,107 nipype.workflow INFO:\n'
# b'\t [MultiProc] Running 32 tasks, and 134 jobs ready. Free memory (GB): 220.29/226.69, Free processors: 0/32.\n'
# b'                     Currently running:\n'
# b'                       * nibetaseries_participant_wf.single_subject018_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject018_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject005_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject005_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject005_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject005_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject005_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject005_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject005_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject005_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject003_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject003_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject003_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject003_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject003_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject003_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node\n'
# b'210220-16:08:42,665 nipype.workflow INFO:\n'
# b'\t [Node] Finished "nibetaseries_participant_wf.single_subject005_wf.betaseries_wf.betaseries_node".\n'
# b'210220-16:08:44,95 nipype.workflow INFO:\n'
# b'\t [Job 32] Completed (nibetaseries_participant_wf.single_subject005_wf.betaseries_wf.betaseries_node).\n'
# b'210220-16:08:44,135 nipype.workflow INFO:\n'
# b'\t [MultiProc] Running 31 tasks, and 135 jobs ready. Free memory (GB): 220.49/226.69, Free processors: 1/32.\n'
# b'                     Currently running:\n'
# b'                       * nibetaseries_participant_wf.single_subject018_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject018_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject005_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject005_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject005_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject005_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject005_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject005_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject005_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject003_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject003_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject003_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject003_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject003_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject003_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node\n'
# b'210220-16:08:46,633 nipype.workflow INFO:\n'
# b'\t [MultiProc] Running 32 tasks, and 137 jobs ready. Free memory (GB): 220.29/226.69, Free processors: 0/32.\n'
# b'                     Currently running:\n'
# b'                       * nibetaseries_participant_wf.single_subject018_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject018_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject018_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject005_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject005_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject005_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject005_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject005_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject005_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject005_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject003_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject003_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject003_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject003_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject003_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject003_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node\n'
# b'210220-16:08:46,653 nipype.workflow INFO:\n'
# b'\t [Node] Setting-up "nibetaseries_participant_wf.single_subject018_wf.betaseries_wf.betaseries_node" in "/mnt/chrastil/lab/users/lily/path_direction/localizer_beta_series_all_run_exploration/derivatives/work/NiBetaSeries_work/nibetaseries_participant_wf/single_subject018_wf/betaseries_wf/04949ac0c510b718e7ff1c42a73c87b568e2d0cb/betaseries_node".\n'
# b'210220-16:08:47,348 nipype.workflow INFO:\n'
# b'\t [Node] Running "betaseries_node" ("nibetaseries.interfaces.nistats.LSABetaSeries")\n'
# b'210220-16:09:25,857 nipype.workflow INFO:\n'
# b'\t [Node] Finished "nibetaseries_participant_wf.single_subject003_wf.betaseries_wf.betaseries_node".\n'
# b'210220-16:09:26,673 nipype.workflow INFO:\n'
# b'\t [Job 22] Completed (nibetaseries_participant_wf.single_subject003_wf.betaseries_wf.betaseries_node).\n'
# b'210220-16:09:26,679 nipype.workflow INFO:\n'
# b'\t [MultiProc] Running 31 tasks, and 138 jobs ready. Free memory (GB): 220.49/226.69, Free processors: 1/32.\n'
# b'                     Currently running:\n'
# b'                       * nibetaseries_participant_wf.single_subject018_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject018_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject018_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject005_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject005_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject005_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject005_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject005_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject005_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject005_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject003_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject003_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject003_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject003_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject003_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node\n'
# b'210220-16:09:27,462 nipype.workflow INFO:\n'
# b'\t [Node] Setting-up "nibetaseries_participant_wf.single_subject018_wf.betaseries_wf.betaseries_node" in "/mnt/chrastil/lab/users/lily/path_direction/localizer_beta_series_all_run_exploration/derivatives/work/NiBetaSeries_work/nibetaseries_participant_wf/single_subject018_wf/betaseries_wf/69196b347cbaaed2dd4d83d05693df8b68c17dcb/betaseries_node".\n'
# b'210220-16:09:28,144 nipype.workflow INFO:\n'
# b'\t [Node] Running "betaseries_node" ("nibetaseries.interfaces.nistats.LSABetaSeries")\n'
# b'210220-16:09:28,676 nipype.workflow INFO:\n'
# b'\t [MultiProc] Running 32 tasks, and 140 jobs ready. Free memory (GB): 220.29/226.69, Free processors: 0/32.\n'
# b'                     Currently running:\n'
# b'                       * nibetaseries_participant_wf.single_subject018_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject018_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject018_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject018_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject005_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject005_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject005_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject005_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject005_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject005_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject005_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject003_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject003_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject003_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject003_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject003_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node\n'
# b'210220-16:09:46,952 nipype.workflow INFO:\n'
# b'\t [Node] Finished "nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node".\n'
# b'210220-16:09:48,700 nipype.workflow INFO:\n'
# b'\t [Job 8] Completed (nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node).\n'
# b'210220-16:09:48,706 nipype.workflow INFO:\n'
# b'\t [MultiProc] Running 31 tasks, and 141 jobs ready. Free memory (GB): 220.49/226.69, Free processors: 1/32.\n'
# b'                     Currently running:\n'
# b'                       * nibetaseries_participant_wf.single_subject018_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject018_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject018_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject018_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject005_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject005_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject005_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject005_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject005_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject005_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject005_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject003_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject003_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject003_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject003_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject003_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node\n'
# b'210220-16:09:49,597 nipype.workflow INFO:\n'
# b'\t [Node] Setting-up "nibetaseries_participant_wf.single_subject018_wf.betaseries_wf.betaseries_node" in "/mnt/chrastil/lab/users/lily/path_direction/localizer_beta_series_all_run_exploration/derivatives/work/NiBetaSeries_work/nibetaseries_participant_wf/single_subject018_wf/betaseries_wf/c827e4a57a395f03087a7ba6dfe7e17682f60e61/betaseries_node".\n'
# b'210220-16:09:50,200 nipype.workflow INFO:\n'
# b'\t [Node] Running "betaseries_node" ("nibetaseries.interfaces.nistats.LSABetaSeries")\n'
# b'210220-16:09:50,703 nipype.workflow INFO:\n'
# b'\t [MultiProc] Running 32 tasks, and 143 jobs ready. Free memory (GB): 220.29/226.69, Free processors: 0/32.\n'
# b'                     Currently running:\n'
# b'                       * nibetaseries_participant_wf.single_subject018_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject018_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject018_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject018_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject018_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject014_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject005_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject005_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject005_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject005_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject005_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject005_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject005_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject003_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject003_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject003_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject003_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject003_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node\n'
# b'                       * nibetaseries_participant_wf.single_subject002_wf.betaseries_wf.betaseries_node\n'
# ...
# b'  minimize_memory=False,\n'
# b'Computing run 1 out of 1 runs (go take a coffee, a big one)\n'
# b'\n'
# b'Computation of 1 runs done in 973 seconds\n'
# b'\n'
# b"/home/lily/.local/lib/python3.6/site-packages/nistats/regression.py:339: FutureWarning: 'resid' from RegressionResults has been deprecated and will be removed. Please use 'residuals' instead.\n"
# b'  FutureWarning,\n'
# b'/home/lily/.local/lib/python3.6/site-packages/nibetaseries/interfaces/nistats.py:216: DeprecationWarning: The parameter "mask" will be removed in next release of Nistats. Please use the parameter "mask_img" instead.\n'
# b'  minimize_memory=False,\n'
# b'Computing run 1 out of 1 runs (go take a coffee, a big one)\n'
# b'\n'
# b'Computation of 1 runs done in 617 seconds\n'
# b'\n'
# b"/home/lily/.local/lib/python3.6/site-packages/nistats/regression.py:339: FutureWarning: 'resid' from RegressionResults has been deprecated and will be removed. Please use 'residuals' instead.\n"
# b'  FutureWarning,\n'
# b'/home/lily/.local/lib/python3.6/site-packages/nibetaseries/interfaces/nistats.py:216: DeprecationWarning: The parameter "mask" will be removed in next release of Nistats. Please use the parameter "mask_img" instead.\n'
# b'  minimize_memory=False,\n'
# b'Computing run 1 out of 1 runs (go take a coffee, a big one)\n'
# b'\n'
# b'Computation of 1 runs done in 1199 seconds\n'
# b'\n'
# b"/home/lily/.local/lib/python3.6/site-packages/nistats/regression.py:339: FutureWarning: 'resid' from RegressionResults has been deprecated and will be removed. Please use 'residuals' instead.\n"
# b'  FutureWarning,\n'
# b'/home/lily/.local/lib/python3.6/site-packages/nibetaseries/interfaces/nistats.py:216: DeprecationWarning: The parameter "mask" will be removed in next release of Nistats. Please use the parameter "mask_img" instead.\n'
# b'  minimize_memory=False,\n'
# b'Computing run 1 out of 1 runs (go take a coffee, a big one)\n'
# b'\n'
# b'Computation of 1 runs done in 1162 seconds\n'
# b'\n'
# b"/home/lily/.local/lib/python3.6/site-packages/nistats/regression.py:339: FutureWarning: 'resid' from RegressionResults has been deprecated and will be removed. Please use 'residuals' instead.\n"
# b'  FutureWarning,\n'
# b'/home/lily/.local/lib/python3.6/site-packages/nibetaseries/interfaces/nistats.py:216: DeprecationWarning: The parameter "mask" will be removed in next release of Nistats. Please use the parameter "mask_img" instead.\n'
# b'  minimize_memory=False,\n'
# b'Computing run 1 out of 1 runs (go take a coffee, a big one)\n'
# b'\n'
# b'Computation of 1 runs done in 849 seconds\n'
# b'\n'
# b"/home/lily/.local/lib/python3.6/site-packages/nistats/regression.py:339: FutureWarning: 'resid' from RegressionResults has been deprecated and will be removed. Please use 'residuals' instead.\n"
# b'  FutureWarning,\n'
# b'/home/lily/.local/lib/python3.6/site-packages/nibetaseries/interfaces/nistats.py:216: DeprecationWarning: The parameter "mask" will be removed in next release of Nistats. Please use the parameter "mask_img" instead.\n'
# b'  minimize_memory=False,\n'
# b'Computing run 1 out of 1 runs (go take a coffee, a big one)\n'
# b'\n'
# b'Computation of 1 runs done in 1534 seconds\n'
# b'\n'
# b"/home/lily/.local/lib/python3.6/site-packages/nistats/regression.py:339: FutureWarning: 'resid' from RegressionResults has been deprecated and will be removed. Please use 'residuals' instead.\n"
# b'  FutureWarning,\n'
# b'/home/lily/.local/lib/python3.6/site-packages/nibetaseries/interfaces/nistats.py:216: DeprecationWarning: The parameter "mask" will be removed in next release of Nistats. Please use the parameter "mask_img" instead.\n'
# b'  minimize_memory=False,\n'
# b'Computing run 1 out of 1 runs (go take a coffee, a big one)\n'
# b'\n'
# b'Computation of 1 runs done in 1317 seconds\n'
# b'\n'
# b"/home/lily/.local/lib/python3.6/site-packages/nistats/regression.py:339: FutureWarning: 'resid' from RegressionResults has been deprecated and will be removed. Please use 'residuals' instead.\n"
# b'  FutureWarning,\n'
# b'/home/lily/.local/lib/python3.6/site-packages/nibetaseries/interfaces/nistats.py:216: DeprecationWarning: The parameter "mask" will be removed in next release of Nistats. Please use the parameter "mask_img" instead.\n'
# b'  minimize_memory=False,\n'
# b'Computing run 1 out of 1 runs (go take a coffee, a big one)\n'
# b'\n'
# b'Computation of 1 runs done in 1586 seconds\n'
# b'\n'
# b"/home/lily/.local/lib/python3.6/site-packages/nistats/regression.py:339: FutureWarning: 'resid' from RegressionResults has been deprecated and will be removed. Please use 'residuals' instead.\n"
# b'  FutureWarning,\n'
# b'/home/lily/.local/lib/python3.6/site-packages/nibetaseries/interfaces/nistats.py:216: DeprecationWarning: The parameter "mask" will be removed in next release of Nistats. Please use the parameter "mask_img" instead.\n'
# b'  minimize_memory=False,\n'
# b'Computing run 1 out of 1 runs (go take a coffee, a big one)\n'
# b'\n'
# b'Computation of 1 runs done in 905 seconds\n'
# b'\n'
# b"/home/lily/.local/lib/python3.6/site-packages/nistats/regression.py:339: FutureWarning: 'resid' from RegressionResults has been deprecated and will be removed. Please use 'residuals' instead.\n"
# b'  FutureWarning,\n'
# b'/home/lily/.local/lib/python3.6/site-packages/nibetaseries/interfaces/nistats.py:216: DeprecationWarning: The parameter "mask" will be removed in next release of Nistats. Please use the parameter "mask_img" instead.\n'
# b'  minimize_memory=False,\n'
# b'Computing run 1 out of 1 runs (go take a coffee, a big one)\n'
# b'\n'
# b'Computation of 1 runs done in 1335 seconds\n'
# b'\n'
# b"/home/lily/.local/lib/python3.6/site-packages/nistats/regression.py:339: FutureWarning: 'resid' from RegressionResults has been deprecated and will be removed. Please use 'residuals' instead.\n"
# b'  FutureWarning,\n'
# b'/home/lily/.local/lib/python3.6/site-packages/nibetaseries/interfaces/nistats.py:216: DeprecationWarning: The parameter "mask" will be removed in next release of Nistats. Please use the parameter "mask_img" instead.\n'
# b'  minimize_memory=False,\n'
# b'Computing run 1 out of 1 runs (go take a coffee, a big one)\n'
# b'\n'
# b'Computation of 1 runs done in 1247 seconds\n'
# b'\n'
# b"/home/lily/.local/lib/python3.6/site-packages/nistats/regression.py:339: FutureWarning: 'resid' from RegressionResults has been deprecated and will be removed. Please use 'residuals' instead.\n"
# b'  FutureWarning,\n'
# b'/home/lily/.local/lib/python3.6/site-packages/nibetaseries/interfaces/nistats.py:216: DeprecationWarning: The parameter "mask" will be removed in next release of Nistats. Please use the parameter "mask_img" instead.\n'
# b'  minimize_memory=False,\n'
# b'Computing run 1 out of 1 runs (go take a coffee, a big one)\n'
# b'\n'
# b'Computation of 1 runs done in 1781 seconds\n'
# b'\n'
# b"/home/lily/.local/lib/python3.6/site-packages/nistats/regression.py:339: FutureWarning: 'resid' from RegressionResults has been deprecated and will be removed. Please use 'residuals' instead.\n"
# b'  FutureWarning,\n'
# b'/home/lily/.local/lib/python3.6/site-packages/nibetaseries/interfaces/nistats.py:216: DeprecationWarning: The parameter "mask" will be removed in next release of Nistats. Please use the parameter "mask_img" instead.\n'
# b'  minimize_memory=False,\n'
# b'Computing run 1 out of 1 runs (go take a coffee, a big one)\n'
# b'\n'
# b'Computation of 1 runs done in 807 seconds\n'
# b'\n'
# b"/home/lily/.local/lib/python3.6/site-packages/nistats/regression.py:339: FutureWarning: 'resid' from RegressionResults has been deprecated and will be removed. Please use 'residuals' instead.\n"
# b'  FutureWarning,\n'
# b'/home/lily/.local/lib/python3.6/site-packages/nibetaseries/interfaces/nistats.py:216: DeprecationWarning: The parameter "mask" will be removed in next release of Nistats. Please use the parameter "mask_img" instead.\n'
# b'  minimize_memory=False,\n'
# b'Computing run 1 out of 1 runs (go take a coffee, a big one)\n'
# b'\n'
# b'Computation of 1 runs done in 1297 seconds\n'
# b'\n'
# b"/home/lily/.local/lib/python3.6/site-packages/nistats/regression.py:339: FutureWarning: 'resid' from RegressionResults has been deprecated and will be removed. Please use 'residuals' instead.\n"
# b'  FutureWarning,\n'
# b'/home/lily/.local/lib/python3.6/site-packages/nibetaseries/interfaces/nistats.py:216: DeprecationWarning: The parameter "mask" will be removed in next release of Nistats. Please use the parameter "mask_img" instead.\n'
# b'  minimize_memory=False,\n'
# b'Computing run 1 out of 1 runs (go take a coffee, a big one)\n'
# b'\n'
# b'Computation of 1 runs done in 906 seconds\n'
# b'\n'
# b"/home/lily/.local/lib/python3.6/site-packages/nistats/regression.py:339: FutureWarning: 'resid' from RegressionResults has been deprecated and will be removed. Please use 'residuals' instead.\n"
# b'  FutureWarning,\n'
# b'/home/lily/.local/lib/python3.6/site-packages/nibetaseries/interfaces/nistats.py:216: DeprecationWarning: The parameter "mask" will be removed in next release of Nistats. Please use the parameter "mask_img" instead.\n'
# b'  minimize_memory=False,\n'
# b'Computing run 1 out of 1 runs (go take a coffee, a big one)\n'
# b'\n'
# b'Computation of 1 runs done in 788 seconds\n'
# b'\n'
# b"/home/lily/.local/lib/python3.6/site-packages/nistats/regression.py:339: FutureWarning: 'resid' from RegressionResults has been deprecated and will be removed. Please use 'residuals' instead.\n"
# b'  FutureWarning,\n'
# b'/home/lily/.local/lib/python3.6/site-packages/nibetaseries/interfaces/nistats.py:216: DeprecationWarning: The parameter "mask" will be removed in next release of Nistats. Please use the parameter "mask_img" instead.\n'
# b'  minimize_memory=False,\n'
# b'Computing run 1 out of 1 runs (go take a coffee, a big one)\n'
# b'\n'
# b'Computation of 1 runs done in 1098 seconds\n'
# b'\n'
# b"/home/lily/.local/lib/python3.6/site-packages/nistats/regression.py:339: FutureWarning: 'resid' from RegressionResults has been deprecated and will be removed. Please use 'residuals' instead.\n"
# b'  FutureWarning,\n'
# b'/home/lily/.local/lib/python3.6/site-packages/nibetaseries/interfaces/nistats.py:216: DeprecationWarning: The parameter "mask" will be removed in next release of Nistats. Please use the parameter "mask_img" instead.\n'
# b'  minimize_memory=False,\n'
# b'Computing run 1 out of 1 runs (go take a coffee, a big one)\n'
# b'\n'
# b'Computation of 1 runs done in 736 seconds\n'
# b'\n'
# b"/home/lily/.local/lib/python3.6/site-packages/nistats/regression.py:339: FutureWarning: 'resid' from RegressionResults has been deprecated and will be removed. Please use 'residuals' instead.\n"
# b'  FutureWarning,\n'
# b'/home/lily/.local/lib/python3.6/site-packages/nibetaseries/interfaces/nistats.py:216: DeprecationWarning: The parameter "mask" will be removed in next release of Nistats. Please use the parameter "mask_img" instead.\n'
# b'  minimize_memory=False,\n'
# b'Computing run 1 out of 1 runs (go take a coffee, a big one)\n'
# b'\n'
# b'Computation of 1 runs done in 971 seconds\n'
# b'\n'
# b"/home/lily/.local/lib/python3.6/site-packages/nistats/regression.py:339: FutureWarning: 'resid' from RegressionResults has been deprecated and will be removed. Please use 'residuals' instead.\n"
# b'  FutureWarning,\n'
# b'/home/lily/.local/lib/python3.6/site-packages/nibetaseries/interfaces/nistats.py:216: DeprecationWarning: The parameter "mask" will be removed in next release of Nistats. Please use the parameter "mask_img" instead.\n'
# b'  minimize_memory=False,\n'
# b'Computing run 1 out of 1 runs (go take a coffee, a big one)\n'
# b'\n'
# b'Computation of 1 runs done in 827 seconds\n'
# b'\n'
# b"/home/lily/.local/lib/python3.6/site-packages/nistats/regression.py:339: FutureWarning: 'resid' from RegressionResults has been deprecated and will be removed. Please use 'residuals' instead.\n"
# b'  FutureWarning,\n'
# b'/home/lily/.local/lib/python3.6/site-packages/nibetaseries/interfaces/nistats.py:216: DeprecationWarning: The parameter "mask" will be removed in next release of Nistats. Please use the parameter "mask_img" instead.\n'
# b'  minimize_memory=False,\n'
# b'Computing run 1 out of 1 runs (go take a coffee, a big one)\n'
# b'\n'
# b'Computation of 1 runs done in 917 seconds\n'
# b'\n'
# b"/home/lily/.local/lib/python3.6/site-packages/nistats/regression.py:339: FutureWarning: 'resid' from RegressionResults has been deprecated and will be removed. Please use 'residuals' instead.\n"
# b'  FutureWarning,\n'
# b'/home/lily/.local/lib/python3.6/site-packages/nibetaseries/interfaces/nistats.py:216: DeprecationWarning: The parameter "mask" will be removed in next release of Nistats. Please use the parameter "mask_img" instead.\n'
# b'  minimize_memory=False,\n'
# b'Computing run 1 out of 1 runs (go take a coffee, a big one)\n'
# b'\n'
# b'Computation of 1 runs done in 1242 seconds\n'
# b'\n'
# b"/home/lily/.local/lib/python3.6/site-packages/nistats/regression.py:339: FutureWarning: 'resid' from RegressionResults has been deprecated and will be removed. Please use 'residuals' instead.\n"
# b'  FutureWarning,\n'
# b'/home/lily/.local/lib/python3.6/site-packages/nibetaseries/interfaces/nistats.py:216: DeprecationWarning: The parameter "mask" will be removed in next release of Nistats. Please use the parameter "mask_img" instead.\n'
# b'  minimize_memory=False,\n'
# b'Computing run 1 out of 1 runs (go take a coffee, a big one)\n'
# b'\n'
# b'Computation of 1 runs done in 731 seconds\n'
# b'\n'
# b"/home/lily/.local/lib/python3.6/site-packages/nistats/regression.py:339: FutureWarning: 'resid' from RegressionResults has been deprecated and will be removed. Please use 'residuals' instead.\n"
# b'  FutureWarning,\n'
# b'/home/lily/.local/lib/python3.6/site-packages/nibetaseries/interfaces/nistats.py:216: DeprecationWarning: The parameter "mask" will be removed in next release of Nistats. Please use the parameter "mask_img" instead.\n'
# b'  minimize_memory=False,\n'
# b'Computing run 1 out of 1 runs (go take a coffee, a big one)\n'
# b'\n'
# b'Computation of 1 runs done in 1121 seconds\n'
# b'\n'
# b"/home/lily/.local/lib/python3.6/site-packages/nistats/regression.py:339: FutureWarning: 'resid' from RegressionResults has been deprecated and will be removed. Please use 'residuals' instead.\n"
# b'  FutureWarning,\n'
# b'/home/lily/.local/lib/python3.6/site-packages/nibetaseries/interfaces/nistats.py:216: DeprecationWarning: The parameter "mask" will be removed in next release of Nistats. Please use the parameter "mask_img" instead.\n'
# b'  minimize_memory=False,\n'
# b'Computing run 1 out of 1 runs (go take a coffee, a big one)\n'
# b'\n'
# b'Computation of 1 runs done in 328 seconds\n'
# b'\n'
# b"/home/lily/.local/lib/python3.6/site-packages/nistats/regression.py:339: FutureWarning: 'resid' from RegressionResults has been deprecated and will be removed. Please use 'residuals' instead.\n"
# b'  FutureWarning,\n'
# b'/home/lily/.local/lib/python3.6/site-packages/nibetaseries/interfaces/nistats.py:216: DeprecationWarning: The parameter "mask" will be removed in next release of Nistats. Please use the parameter "mask_img" instead.\n'
# b'  minimize_memory=False,\n'
# b'Computing run 1 out of 1 runs (go take a coffee, a big one)\n'
# b'\n'
# b'Computation of 1 runs done in 1034 seconds\n'
# b'\n'
# b"/home/lily/.local/lib/python3.6/site-packages/nistats/regression.py:339: FutureWarning: 'resid' from RegressionResults has been deprecated and will be removed. Please use 'residuals' instead.\n"
# b'  FutureWarning,\n'
# b'/home/lily/.local/lib/python3.6/site-packages/nibetaseries/interfaces/nistats.py:216: DeprecationWarning: The parameter "mask" will be removed in next release of Nistats. Please use the parameter "mask_img" instead.\n'
# b'  minimize_memory=False,\n'
# b'Computing run 1 out of 1 runs (go take a coffee, a big one)\n'
# b'\n'
# b'Computation of 1 runs done in 1352 seconds\n'
# b'\n'
# b"/home/lily/.local/lib/python3.6/site-packages/nistats/regression.py:339: FutureWarning: 'resid' from RegressionResults has been deprecated and will be removed. Please use 'residuals' instead.\n"
# b'  FutureWarning,\n'
