# %%
import tempfile  # make a temporary directory for files
import os  # interact with the filesystem
import urllib.request  # grad data from internet
import tarfile  # extract files from tar
from subprocess import Popen, PIPE, STDOUT  # enable calling commandline

import matplotlib.pyplot as plt  # manipulate figures
import seaborn as sns  # display results
import pandas as pd   # manipulate tabular data
import nibabel as nib  # load the beta maps in python
from nilearn import plotting  # plot nifti images


from nilearn import plotting
from nilearn.image import mean_img

from nilearn.plotting import plot_glass_brain

# %%
sub_num = "sub-*"

# %%
data_dir1 = '/mnt/chrastil/lab/users/lily/path_direction/localizer_beta_series_all_run_exploration'
data_name_S1 = sub_num+ '_task-boldEx*_run-*_space-MNI152NLin2009cAsym_desc-S_betaseries.nii.gz'
data_name_E1 = sub_num+  '_task-boldEx*_run-*_space-MNI152NLin2009cAsym_desc-E_betaseries.nii.gz'
data_name_W1 = sub_num+  '_task-boldEx*_run-*_space-MNI152NLin2009cAsym_desc-W_betaseries.nii.gz'
data_name_N1 = sub_num+  '_task-boldEx*_run-*_space-MNI152NLin2009cAsym_desc-N_betaseries.nii.gz'

# %%
data_dir2 = '/mnt/chrastil/lab/users/lily/path_direction/localizer_beta_series_all_run_exploration'
data_name_S3 = sub_num+  '_task-boldRun*_run-*_space-MNI152NLin2009cAsym_desc-S_betaseries.nii.gz'
data_name_E3 = sub_num+  '_task-boldRun*_run-*_space-MNI152NLin2009cAsym_desc-E_betaseries.nii.gz'
data_name_W3 = sub_num+  '_task-boldRun*_run-*_space-MNI152NLin2009cAsym_desc-W_betaseries.nii.gz'
data_name_N3 = sub_num+  '_task-boldRun*_run-*_space-MNI152NLin2009cAsym_desc-N_betaseries.nii.gz'

# %%
S_path1 = os.path.join(data_dir1, "derivatives","nibetaseries_no_atlas",sub_num,"func",data_name_S1)
E_path1 = os.path.join(data_dir1, "derivatives","nibetaseries_no_atlas",sub_num,"func",data_name_E1)
W_path1 = os.path.join(data_dir1, "derivatives","nibetaseries_no_atlas",sub_num,"func",data_name_W1)
N_path1 = os.path.join(data_dir1, "derivatives","nibetaseries_no_atlas",sub_num,"func",data_name_N1)


S_path3 = os.path.join(data_dir2, "derivatives","nibetaseries_no_atlas",sub_num,"func",data_name_S3)
E_path3 = os.path.join(data_dir2, "derivatives","nibetaseries_no_atlas",sub_num,"func",data_name_E3)
W_path3 = os.path.join(data_dir2, "derivatives","nibetaseries_no_atlas",sub_num,"func",data_name_W3)
N_path3 = os.path.join(data_dir2, "derivatives","nibetaseries_no_atlas",sub_num,"func",data_name_N3)

# %%
# plotting.view_img(mean_img(S_path3), threshold= 10)

# %% [markdown]
# # EXPLORE1

# %% [markdown]
# ## EXPLORE1 EAST

# %%
plot_glass_brain(mean_img(E_path1), threshold = 0, vmax = 1.9, colorbar = True)

# %% [markdown]
# ## EXPLORE1 SOUTH

# %%
plot_glass_brain(mean_img(S_path1), threshold = 0, vmax = 1.9, colorbar = True)

# %% [markdown]
# ## EXPLORE1 WEST

# %%
plot_glass_brain(mean_img(W_path1), threshold = 0, vmax = 1.9, colorbar = True)

# %% [markdown]
# ## EXPLORE1 NORTH

# %%
plot_glass_brain(mean_img(N_path1),threshold = 0, vmax = 1.9,  colorbar = True)

# %% [markdown]
# # Run 1

# %% [markdown]
# ## Run1 EAST

# %%
plot_glass_brain(mean_img(E_path3), threshold = 0, vmax = 1.9, colorbar = True)

# %% [markdown]
# ## Run1 SOUTH

# %%
plot_glass_brain(mean_img(S_path3), threshold = 0, vmax = 1.9, colorbar = True)

# %% [markdown]
# ## Run1 WEST

# %%
plot_glass_brain(mean_img(W_path3), threshold = 0, vmax = 1.9, colorbar = True)

# %% [markdown]
# ## Run1 NORTH

# %%
plot_glass_brain(mean_img(N_path3),threshold = 0, vmax = 1.9, colorbar = True)
