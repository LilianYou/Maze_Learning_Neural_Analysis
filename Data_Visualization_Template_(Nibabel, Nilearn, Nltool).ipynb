# %% [markdown]
# ## bids

# %%
#! pip install pybids

# %%
from bids import BIDSLayout, BIDSValidator
import os

# %%
data_dir = '/mnt/chrastil/lab/users/lily/localizer'
layout = BIDSLayout(data_dir, derivatives = True)
layout
# Out:
# BIDS Layout: ...astil/lab/users/lily/localizer | Subjects: 1 | Sessions: 0 | Runs: 2

# %%
# get list of unique subjects
layout.get_subjects()
# Out:
# ['033']

# %%
all_files = layout.get()
print("There are {} files in the layout.".format(len(all_files)))
print("\nThe first 10 files are:")
all_files[:10]
# Out:
# There are 1021 files in the layout.
#
# The first 10 files are:
# [<BIDSJSONFile filename='/mnt/chrastil/lab/users/lily/localizer/dataset_description.json'>,
#  <BIDSJSONFile filename='/mnt/chrastil/lab/users/lily/localizer/derivatives/dataset_description.json'>,
#  <BIDSJSONFile filename='/mnt/chrastil/lab/users/lily/localizer/derivatives/fmriprep/dataset_description.json'>,
#  <BIDSDataFile filename='/mnt/chrastil/lab/users/lily/localizer/derivatives/fmriprep/desc-aparcaseg_dseg.tsv'>,
#  <BIDSDataFile filename='/mnt/chrastil/lab/users/lily/localizer/derivatives/fmriprep/desc-aseg_dseg.tsv'>,
#  <BIDSFile filename='/mnt/chrastil/lab/users/lily/localizer/derivatives/fmriprep/logs/CITATION.bib'>,
#  <BIDSFile filename='/mnt/chrastil/lab/users/lily/localizer/derivatives/fmriprep/logs/CITATION.html'>,
#  <BIDSFile filename='/mnt/chrastil/lab/users/lily/localizer/derivatives/fmriprep/logs/CITATION.md'>,
# ...

# %%
layout.get(return_type='filename')[:10]
# Out:
# ['/mnt/chrastil/lab/users/lily/localizer/dataset_description.json',
#  '/mnt/chrastil/lab/users/lily/localizer/derivatives/dataset_description.json',
#  '/mnt/chrastil/lab/users/lily/localizer/derivatives/fmriprep/dataset_description.json',
#  '/mnt/chrastil/lab/users/lily/localizer/derivatives/fmriprep/desc-aparcaseg_dseg.tsv',
#  '/mnt/chrastil/lab/users/lily/localizer/derivatives/fmriprep/desc-aseg_dseg.tsv',
#  '/mnt/chrastil/lab/users/lily/localizer/derivatives/fmriprep/logs/CITATION.bib',
#  '/mnt/chrastil/lab/users/lily/localizer/derivatives/fmriprep/logs/CITATION.html',
#  '/mnt/chrastil/lab/users/lily/localizer/derivatives/fmriprep/logs/CITATION.md',
#  '/mnt/chrastil/lab/users/lily/localizer/derivatives/fmriprep/logs/CITATION.tex',
#  '/mnt/chrastil/lab/users/lily/localizer/derivatives/fmriprep/sub-033.html']

# %%
# get filenames of all bold time series for subject '033'
layout.get(subject='033', extension='nii.gz', suffix='bold', return_type='filename')
# Out:
# ['/mnt/chrastil/lab/users/lily/localizer/derivatives/fmriprep/sub-033/func/sub-033_task-boldEx2_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz',
#  '/mnt/chrastil/lab/users/lily/localizer/derivatives/fmriprep/sub-033/func/sub-033_task-boldEx_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz',
#  '/mnt/chrastil/lab/users/lily/localizer/derivatives/fmriprep/sub-033/func/sub-033_task-boldRun1_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz',
#  '/mnt/chrastil/lab/users/lily/localizer/derivatives/fmriprep/sub-033/func/sub-033_task-boldRun1_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz',
#  '/mnt/chrastil/lab/users/lily/localizer/derivatives/fmriprep/sub-033/func/sub-033_task-boldRun2_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz',
#  '/mnt/chrastil/lab/users/lily/localizer/derivatives/fmriprep/sub-033/func/sub-033_task-boldRun3_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz',
# ...

# %%
# get metadata for an image
target = '/mnt/chrastil/lab/users/lily/localizer/derivatives/fmriprep/sub-033/func/sub-033_task-rest_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz'
layout.get_metadata(target)
# Out:
# {'RepetitionTime': 0.72, 'SkullStripped': True, 'TaskName': 'rest'}

# %%
# Retrieve all files where SamplingFrequency (a metadata key) = 100
# and acquisition = prefrontal, for the first two subjects
layout.get(subject=['033'], acquisition="events")
# Out:
# []

# %%
layout.get(target='subject', return_type='id')[:10] # return the first 10 subject ids
# Out:
# ['033']

# %%
layout.get(target='subject', scope='derivatives', suffix='bold', return_type='file')[:10] # query image file names
# Out:
# ['/mnt/chrastil/lab/users/lily/localizer/derivatives/fmriprep/sub-033/figures/sub-033_task-boldEx2_run-1_desc-bbregister_bold.svg',
#  '/mnt/chrastil/lab/users/lily/localizer/derivatives/fmriprep/sub-033/figures/sub-033_task-boldEx2_run-1_desc-carpetplot_bold.svg',
#  '/mnt/chrastil/lab/users/lily/localizer/derivatives/fmriprep/sub-033/figures/sub-033_task-boldEx2_run-1_desc-compcorvar_bold.svg',
#  '/mnt/chrastil/lab/users/lily/localizer/derivatives/fmriprep/sub-033/figures/sub-033_task-boldEx2_run-1_desc-confoundcorr_bold.svg',
#  '/mnt/chrastil/lab/users/lily/localizer/derivatives/fmriprep/sub-033/figures/sub-033_task-boldEx2_run-1_desc-fieldmap_bold.svg',
#  '/mnt/chrastil/lab/users/lily/localizer/derivatives/fmriprep/sub-033/figures/sub-033_task-boldEx2_run-1_desc-magnitude_bold.svg',
#  '/mnt/chrastil/lab/users/lily/localizer/derivatives/fmriprep/sub-033/figures/sub-033_task-boldEx2_run-1_desc-rois_bold.svg',
# ...

# %%
f = layout.get()[0]
f
# Out:
# <BIDSJSONFile filename='/mnt/chrastil/lab/users/lily/localizer/dataset_description.json'>

# %%
f.path
# Out:
# '/mnt/chrastil/lab/users/lily/localizer/dataset_description.json'

# %%
layout.get_task() #getting a list of tasks included in the dataset
# Out:
# ['boldEx',
#  'boldEx2',
#  'boldRun1',
#  'boldRun2',
#  'boldRun3',
#  'boldRun4',
#  'boldRun5',
#  'boldRun6',
#  'rest']

# %%
layout.get(task='localizer', suffix='bold', scope='derivatives')[:10]
# Out:
# []

# %%
f = layout.get()[0].filename
f
# Out:
# 'dataset_description.json'

# %%
layout.to_df()
# Out:
# entity                                               path datatype extension  \
# 0       /mnt/chrastil/lab/users/lily/localizer/dataset...      NaN      json
# 1       /mnt/chrastil/lab/users/lily/localizer/sub-033...     anat      json
# 2       /mnt/chrastil/lab/users/lily/localizer/sub-033...     anat    nii.gz
# 3       /mnt/chrastil/lab/users/lily/localizer/sub-033...     anat      json
# 4       /mnt/chrastil/lab/users/lily/localizer/sub-033...     anat    nii.gz
# ...                                                   ...      ...       ...
# 1016    /mnt/chrastil/lab/users/lily/localizer/derivat...      NaN       NaN
# 1017    /mnt/chrastil/lab/users/lily/localizer/derivat...      NaN       NaN
# 1018    /mnt/chrastil/lab/users/lily/localizer/derivat...      NaN       NaN
# 1019    /mnt/chrastil/lab/users/lily/localizer/derivat...      NaN       NaN
# 1020    /mnt/chrastil/lab/users/lily/localizer/derivat...      NaN       NaN
#
# ...

# %% [markdown]
# ## Nibabel

# %%
import nibabel as nib

# %%
data = nib.load(layout.get(subject='033', scope='derivatives', suffix='T1w', return_type='file', extension='nii.gz')[1])

# %%
data?

# %%
data.shape
# Out:
# (193, 229, 193)

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

plt.imshow(data.get_fdata()[:,:,70])

# %%
header = data.header
print(header)
# Out:
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : b''
# db_name         : b''
# extents         : 0
# session_error   : 0
# regular         : b'r'
# dim_info        : 0
# dim             : [  3 193 229 193   1   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [1. 1. 1. 1. 0. 0. 0. 0.]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 2
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : b'xform matrices modified by FixHeaderApplyTransforms (niworkflows v0.10.1).'
# aux_file        : b''
# qform_code      : mni
# sform_code      : mni
# quatern_b       : 0.0
# quatern_c       : 0.0
# ...

# %%
data.affine
# Out:
# array([[   1.,    0.,    0.,  -96.],
#        [   0.,    1.,    0., -132.],
#        [   0.,    0.,    1.,  -78.],
#        [   0.,    0.,    0.,    1.]])

# %% [markdown]
# ## Nilearn

# %%
# %matplotlib inline

from nilearn.plotting import view_img, plot_glass_brain, plot_anat, plot_epi

# %%
plot_anat(data)

# %%
plot_anat(data, draw_cross=False, display_mode='y')

# %%
view_img(data)
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;title&gt;Slice viewer&lt;/title&gt;
#     &lt;meta charset=&quot;UTF-8&quot; /&gt;
# &lt;/head&gt;
# &lt;body&gt;
#   &lt;div id=&quot;div_viewer&quot;&gt;
#     &lt;!-- this is the canvas that will feature the brain slices --&gt;
#     &lt;canvas id=&quot;3Dviewer&quot;&gt;
#     &lt;!-- load a hidden version of the sprite image that includes all (sagital) brain slices --&gt;
#     &lt;img id=&quot;spriteImg&quot; class=&quot;hidden&quot; src=&quot;data:image/png;base64,...&quot; alt=&quot;background&quot; /&gt;
#     &lt;!-- the colormap --&gt;
#     &lt;img id=&quot;colorMap&quot; class=&quot;hidden&quot; src=&quot;...&quot; alt=&quot;colormap&quot;&gt;
#     &lt;!-- another sprite image, with an overlay--&gt;
#     &lt;img id=&quot;overlayImg&quot; class=&quot;hidden&quot; src=&quot;data:image/png;base64,...&quot; alt=&quot;overlay&quot;&gt;
#     &lt;/canvas&gt;
#   &lt;/div&gt;
#
# ...

# %%
# try out after get masks
amygdala_mask = nib.load(os.path.join('..', 'masks', 'FSL_BAmyg_thr0.nii.gz'))
view_img(amygdala_mask, data)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/nibabel/loadsave.py in load(filename, **kwargs)
#      41     try:
# ---> 42         stat_result = os.stat(filename)
#      43     except OSError:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../masks/FSL_BAmyg_thr0.nii.gz'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-131-f0f4f8542723> in <module>
# ----> 1 amygdala_mask = nib.load(os.path.join('..', 'masks', 'FSL_BAmyg_thr0.nii.gz'))
#       2 view_img(amygdala_mask, data)
#
# ~/.local/lib/python3.7/site-packages/nibabel/loadsave.py in load(filename, **kwargs)
#      42         stat_result = os.stat(filename)
#      43     except OSError:
# ...

# %%
# We can also plot a glass brain which allows us to see through the brain from different slice orientations.
plot_glass_brain(amygdala_mask)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-132-d9b0ca8719f0> in <module>
# ----> 1 plot_glass_brain(amygdala_mask)
#
# NameError: name 'amygdala_mask' is not defined

# %% [markdown]
# ## Nltool

# %%
# pip install git+https://github.com/ljchang/neurolearn

# %%
from nltools.data import Brain_Data
from nltools.utils import get_anatomical
# Out:
# /mnt/chrastil/lab/snlbin/programs/mnt/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.linear_model.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.linear_model. Anything that cannot be imported from sklearn.linear_model is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
anat = Brain_Data(get_anatomical())
anat
# Out:
# nltools.data.brain_data.Brain_Data(data=(238955,), Y=0, X=(0, 0), mask=MNI152_T1_2mm_brain_mask.nii.gz, output_file=[])

# %%
print(vars(anat))
# Out:
# {'mask': <nibabel.nifti1.Nifti1Image object at 0x7f5f8115e410>, 'nifti_masker': NiftiMasker(detrend=False, dtype=None, high_pass=None, low_pass=None,
#             mask_args=None,
#             mask_img=<nibabel.nifti1.Nifti1Image object at 0x7f5f8115e410>,
#             mask_strategy='background', memory=Memory(cachedir=None),
#             memory_level=1, reports=True, sample_mask=None, sessions=None,
#             smoothing_fwhm=None, standardize=False, t_r=None,
#             target_affine=None, target_shape=None, verbose=0), 'data': array([1875., 2127., 2182., ..., 5170., 5180., 2836.], dtype=float32), 'Y': Empty DataFrame
# Columns: []
# Index: [], 'X': Empty DataFrame
# Columns: []
# Index: [], 'file_name': []}

# %%
print(dir(anat))
# Out:
# ['X', 'Y', '__add__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__mul__', '__ne__', '__new__', '__radd__', '__reduce__', '__reduce_ex__', '__repr__', '__rmul__', '__rsub__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__weakref__', 'aggregate', 'align', 'append', 'apply_mask', 'astype', 'bootstrap', 'copy', 'data', 'decompose', 'detrend', 'distance', 'dtype', 'empty', 'extract_roi', 'file_name', 'filter', 'find_spikes', 'groupby', 'icc', 'iplot', 'isempty', 'mask', 'mean', 'median', 'multivariate_similarity', 'nifti_masker', 'plot', 'predict', 'predict_multi', 'r_to_z', 'randomise', 'regions', 'regress', 'scale', 'shape', 'similarity', 'smooth', 'standardize', 'std', 'sum', 'threshold', 'to_nifti', 'transform_pairwise', 'ttest',
# ...

# %%
# loading data can be a bit slow
data = Brain_Data(layout.get(target='subject', scope='derivatives', suffix='bold', extension='nii.gz', return_type='file')[0])

# %%
data
# Out:
# nltools.data.brain_data.Brain_Data(data=(674, 238955), Y=0, X=(0, 0), mask=MNI152_T1_2mm_brain_mask.nii.gz, output_file=[])

# %%
print(len(data))
# Out:
# 674

# %%
print(data.shape())
# Out:
# (674, 238955)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.plot(data.mean(axis=1))

# %%
f = data.mean().plot()
# Out:
# threshold is ignored for simple axial plots

# %%
f = data.mean().plot()
# Out:
# threshold is ignored for simple axial plots

# %%
plot_glass_brain(data.mean().to_nifti())

# %%
from IPython.display import HTML

# %%
HTML('derivatives/fmriprep/sub-033.html')
# Out:
# derivatives/fmriprep/sub-033.html
